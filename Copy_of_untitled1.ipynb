# %% [markdown]
# <a href="https://colab.research.google.com/github/aniyodta-sys/BDATA200/blob/main/Copy_of_untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# Raw URL for the CSV file
csv_url = "https://raw.githubusercontent.com/aniyodta-sys/BDATA200/refs/heads/main/Data/mental_health_burnout_tech_2026.csv"

# Load the CSV file into a pandas DataFrame
df = pd.read_csv(csv_url)

# Display the first 5 rows of the DataFrame
display(df.head())
# Out:
#    employee_id  age             gender country              job_role  \
# 0            1   33               Male   India     Software Engineer
# 1            2   24         Non-binary     USA  Full Stack Developer
# 2            3   36  Prefer not to say     USA     Software Engineer
# 3            4   38         Non-binary     USA     Software Engineer
# 4            5   22         Non-binary  France           ML Engineer
#
#   seniority_level  years_experience  years_at_company    company_size  \
# 0            Lead                11               6.4  Small (51-200)
# 1         Manager                 0               5.7  Startup (1-50)
# 2            Lead                14               5.6  Mid (201-1000)
# 3            Lead                14               1.2  Mid (201-1000)
# 4          Junior                 0               3.0  Small (51-200)
#
#           industry  ... autonomy_score  stress_score  burnout_score  \
# ...
